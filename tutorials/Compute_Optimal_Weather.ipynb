# %% [markdown]
# # Computing Weather for Each Flight Optimal Route with Parallelization

# %%
import sys
# This variable should indicate the path from this Jupyter Notebook to the root directory of the repo.
root_path = '../'
# Adds the repo's root to the list of paths
sys.path.append(root_path)

# Package to read yml files
import yaml
# Package to handle file paths
import os
# Package to deal with DataFrames
import pandas as pd
# Package to plot stuff
import matplotlib.pyplot as plt
# Package for numerical and array handling
import numpy as np
# Package to read and write to .sqlite files
import sqlite3
# Package to keep track of time
import datetime

# Function to clear output from jupyter notebook
from IPython.display import clear_output
# Package for compressing dataframes into file
from src.data import compressors
# Package for defining and fitting weather models
from src.models import weather
# Utilities package
from src.common import utils
# Package for interpolating and estimating weather
from src.analysis import weather_interpolator

# Path from this notebook to the root directory
root_path = os.path.normpath(root_path)
# Path from root to the desired config file
config_path_from_root = os.path.normpath('config/config.yml')
# Defining path from this notebook to config file
config_path = os.path.join(root_path, config_path_from_root)

# Loading config file
with open(config_path, 'r',  encoding='utf8') as file:
    config = yaml.safe_load(file)

# Defining "clear-output" function to feed into logger
def clear():
    clear_output(wait=True)

# Creates an instance of a logger class to log all that happens, optional (but encouraged).
logger = utils.Logger(config, clear_function=None)

config['statistics']['interpolation']['flights']['step'] = 600
# Creates an instance of the weather interpolator
interpolator = weather_interpolator.WeatherInterpolator(config, logger=logger)

# Defining location of data
flights_database = '../data/flight/KDEN_KSEA_2023-01-01_2023-01-31.sqlite'
weather_database = '../data/weather/Weather-US_2022-12-31_2023-02-01.sqlite'

# Path to file keeping track of already-loaded flights
tracking_file = flights_database.replace('sqlite','txt')

# %%
import concurrent.futures

# Path to file keeping track of already-loaded flights
tracking_file = flights_database.replace('sqlite', 'txt')

flights_connection = sqlite3.connect(flights_database)
weather_connection = sqlite3.connect(weather_database)
# Declares a cursor to write to the database
cursor = flights_connection.cursor()

# Checking and loading the tracking_file
if os.path.isfile(tracking_file):
    with open(tracking_file, 'r') as f:
        loaded_ids = f.read().split('\n')
        loaded_ids = [i for i in loaded_ids if i != '']
else:
    with open(tracking_file, 'w') as f:
        loaded_ids = []

# Runs a query to identify all the flight_ids available
flight_ids = pd.read_sql_query("SELECT flight_id FROM flights;", flights_connection).values[:,0]
# Only care about the ids that have not been loaded yet.
flight_ids = [f for f in flight_ids if f not in loaded_ids]

# Loading the time threshold variable, which is the time interval that weather data will be loaded for each calculation.
time_thresh = config['statistics']['interpolation']['weather']['time-thresh']
lat_lon_thresh = config['statistics']['interpolation']['weather']['lat-lon-thresh']

# The list of columns to be added to the new table to be created.
new_columns = ['tmpf', 'air_pressure', 'air_density', 'clouds', 'sknt', 'severity']

# If there is no record of loaded ids, we start from scratch
if len(loaded_ids) == 0:
    # Drop the table if it exists
    cursor.execute("DROP TABLE IF EXISTS optimal_state_vector_weather;")

    # Create the new table
    create_table_query = f'''
        CREATE TABLE optimal_state_vector_weather (
            flight_id TEXT,
            {", ".join([f"{col} REAL" for col in new_columns])}
        );
    '''
    # Create the new table if it doesn't exist
    cursor.execute(create_table_query)

# Commits change to file
flights_connection.commit()
# Closing connections
flights_connection.close()
weather_connection.close()

t_start_full = datetime.datetime.now()

count = 0

num_cores = os.cpu_count()

def main_computation(i, flight_id):
    flights_connection = sqlite3.connect(flights_database)
    weather_connection = sqlite3.connect(weather_database)

    # Finds minimum and maximum flight for current flight
    min_time, max_time = pd.read_sql_query(f"""
                                SELECT MIN(time) as min_time, MAX(time) as max_time
                                FROM state_vectors
                                JOIN flights ON flights.flight_id = state_vectors.flight_id
                                WHERE state_vectors.flight_id = "{flight_id}";
                               """,
                              flights_connection
                              ).values[0]

    # Finds the minimum and maximum latitudes for the current flight
    min_latitude, max_latitude = pd.read_sql_query(f"""
                                    SELECT MIN(lat) as min_lat, MAX(lat) as max_lat
                                    FROM state_vectors
                                    JOIN flights ON flights.flight_id = state_vectors.flight_id
                                    WHERE state_vectors.flight_id = "{flight_id}"
                                   """,
                                  flights_connection
                                  ).values[0]

    # Finds the minimum and maximum longitudes for the current flight
    min_longitude, max_longitude = pd.read_sql_query(f"""
                                    SELECT MIN(lon) as min_lon, MAX(lon) as max_lon
                                    FROM state_vectors
                                    JOIN flights ON flights.flight_id = state_vectors.flight_id
                                    WHERE state_vectors.flight_id = "{flight_id}"
                                   """,
                                  flights_connection
                                  ).values[0]

    # Adjusting time, lat and lon thresholds.
    # Adds time threshold to time limits
    min_time -= time_thresh
    max_time += time_thresh

    # Adds latitude and longitude threshold
    range_latitude = max_latitude - min_latitude
    range_longitude = max_longitude - min_longitude
    min_latitude -= range_latitude*lat_lon_thresh
    max_latitude += range_latitude*lat_lon_thresh
    min_longitude -= range_longitude*lat_lon_thresh
    max_longitude += range_longitude*lat_lon_thresh

    # Loads the weather data corresponding to the flight
    flight_weather_data = pd.read_sql_query(f"""
                                    SELECT ws.lat, ws.lon, ws.elevation, ws.sigma, wd.*
                                    FROM weather_data as wd
                                    JOIN weather_stations as ws ON ws.station_id = wd.station_id
                                    WHERE wd.time BETWEEN {min_time} AND {max_time};
                                   """,
                                   weather_connection
                                    )

    # Loads state vectors for the given flight

    optimal_state_vectors = pd.read_sql_query(f"""
        SELECT sv.*
        FROM state_vectors AS sv
        INNER JOIN (
            SELECT of.flight_id
            FROM flights AS fs
            JOIN flights_aircraft AS fa ON fs.icao24 = fa.icao24
            JOIN optimal_flights AS of ON fa.typecode = of.typecode
            WHERE fs.flight_id = "{flight_id}"
        ) AS optimal_flight_id ON sv.flight_id = optimal_flight_id.flight_id;
        """,
        flights_connection)

    optimal_state_vectors['time'] = [min_time + time_thresh - i for i in range(len(optimal_state_vectors))]

    # Computes the weather values for the current flight
    optimal_state_vectors = interpolator.compute_flight_weather_quantities(new_columns, optimal_state_vectors, stations_data=flight_weather_data)

    # Extract the directory and filename
    directory, filename = os.path.split(flights_database)

    # Modify the filename
    # Insert 'optimal_' at the beginning and replace '.sqlite' with '_{flight_id}.csv'
    filename = 'optimal_' + filename.replace('.sqlite', f'_{flight_id}.csv')

    # Combine the directory and the modified filename
    csv_file = os.path.join(directory, filename)
    
    optimal_state_vectors[['flight_id'] + new_columns].to_csv(csv_file)
    
    flights_connection.close()
    weather_connection.close()
    
    time_iteration = datetime.datetime.now()
    time_elapsed = (time_iteration - t_start_full).total_seconds()
    if i == 0:
        ETA = np.nan
    else:
        ETA = time_elapsed*len(flight_ids)/i - time_elapsed
    clear_output(wait=True)
    print(f'{i}/{len(flight_ids)}.')
    print(f'Time Elapsed: {utils.format_time(time_elapsed)}.')
    print(f'Estimate time to finish: {utils.format_time(ETA)}.')

with concurrent.futures.ThreadPoolExecutor(max_workers=num_cores) as executor:
    futures = [executor.submit(main_computation, i, flight_id) for i, flight_id in enumerate(flight_ids)]
    for future in concurrent.futures.as_completed(futures):
        try:
            result = future.result()
        except Exception as e:
            print(f"An error occurred: {e}")

# for i, flight_id in enumerate(flight_ids):
#     main_computation(i, flight_id)
    
import os
csv_files = ['../data/flight/' + f for f in os.listdir('../data/flight') if f.startswith('optimal_' + flights_database.split('/')[-1].replace('.sqlite','')) and f.endswith('.csv')]

flights_connection = sqlite3.connect(flights_database)
cursor = flights_connection.cursor()

for file in csv_files:
    optimal_state_vectors_weather = pd.read_csv(file, index_col=0)
    clear_output(wait=True)
    print(file)
    for index, row in optimal_state_vectors_weather.iterrows():
        # Preparing the data to be inserted
        insert_data = tuple(row[col] for col in ['flight_id'] + new_columns)

        # Creating query to insert new values
        insert_query = f'''
            INSERT INTO optimal_state_vector_weather (flight_id, {', '.join(new_columns)})
            VALUES ({', '.join('?' * len(insert_data))})
        '''
        cursor.execute(insert_query, insert_data)
    # Commiting changes to the database
    flights_connection.commit()

flights_connection.close()
# Out:
# 87/649.
# Time Elapsed: 1h 4m 29s.
# Estimate time to finish: 6h 56m 34s.

# %%
csv_files = ['../data/flight/' + f for f in os.listdir('../data/flight') if f.startswith('optimal_' + flights_database.split('/')[-1].replace('.sqlite','')) and f.endswith('.csv')]

flights_connection = sqlite3.connect(flights_database)
cursor = flights_connection.cursor()

for file in csv_files:
    optimal_state_vectors_weather = pd.read_csv(file, index_col=0)
    clear_output(wait=True)
    print(file)
    for index, row in optimal_state_vectors_weather.iterrows():
        # Preparing the data to be inserted
        insert_data = tuple(row[col] for col in ['flight_id'] + new_columns)

        # Creating query to insert new values
        insert_query = f'''
            INSERT INTO optimal_state_vector_weather (flight_id, {', '.join(new_columns)})
            VALUES ({', '.join('?' * len(insert_data))})
        '''
        cursor.execute(insert_query, insert_data)
    # Commiting changes to the database
    flights_connection.commit()

flights_connection.close()
# Out:
# ../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a335ad_1672966747_1672975259_KDEN_KSEA.csv

# %%
# Out:
# 648/649.
# Time Elapsed: 12h 44m 59s.
# Estimate time to finish: 1m 10s.

# %%
optimal_state_vectors
# Out:
#       vector_id                               flight_id        time  \
# 0       2326505  a44565_1673808290_1673816496_KDEN_KSEA  1675198137
# 1       2326506  a44565_1673808290_1673816496_KDEN_KSEA  1675198136
# 2       2326507  a44565_1673808290_1673816496_KDEN_KSEA  1675198135
# 3       2326508  a44565_1673808290_1673816496_KDEN_KSEA  1675198134
# 4       2326509  a44565_1673808290_1673816496_KDEN_KSEA  1675198133
# ...         ...                                     ...         ...
# 8104    2334609  a44565_1673808290_1673816496_KDEN_KSEA  1675190033
# 8105    2334610  a44565_1673808290_1673816496_KDEN_KSEA  1675190032
# 8106    2334611  a44565_1673808290_1673816496_KDEN_KSEA  1675190031
# 8107    2334612  a44565_1673808290_1673816496_KDEN_KSEA  1675190030
# 8108    2334613  a44565_1673808290_1673816496_KDEN_KSEA  1675190029
#
#       time_normalized        lat         lon  geoaltitude  baroaltitude  \
# 0                   0  39.891403 -104.696244  1684.020000   1836.420000
# 1                   1  39.892367 -104.696237  1701.028727   1853.428727
# 2                   2  39.893331 -104.696229  1718.037455   1870.437455
# 3                   3  39.894295 -104.696222  1735.046182   1887.446182
# 4                   4  39.895259 -104.696215  1752.054909   1904.454909
# ...               ...        ...         ...          ...           ...
# 8104             8104  47.524300 -122.317834   475.977455    674.097455
# 8105             8105  47.523601 -122.317834   471.283091    669.403091
# 8106             8106  47.522901 -122.317834   466.588727    664.708727
# 8107             8107  47.522202 -122.317834   461.894364    660.014364
# 8108             8108  47.521502 -122.317834   457.200000    655.320000
#
#          heading    velocity       tmpf  air_pressure  air_density    clouds  \
# 0       0.000000  106.489908  17.637999    821.549646     1.079320  0.000000
# 1       0.103302  106.364528  17.535467    820.750715     1.078381  0.000000
# 2       0.206605  106.239149  17.432935    819.951783     1.077442  0.000000
# 3       0.309907  106.113769  17.330403    819.152852     1.076503  0.000000
# 4       0.413210  105.988389  17.227871    818.353920     1.075565  0.000000
# ...          ...         ...        ...           ...          ...       ...
# 8104  179.979882   79.730740 -98.667206    179.199002     0.311247  0.799954
# 8105  179.797681   79.477219 -98.667206    179.199002     0.311247  0.799954
# 8106  179.615480   79.223698 -98.667206    179.199002     0.311247  0.799954
# 8107  179.433279   78.970177 -98.667206    179.199002     0.311247  0.799954
# 8108  179.251078   78.716656 -98.667206    179.199002     0.311247  0.799954
#
#             sknt  severity
# 0       3.560400       0.0
# 1       3.759182       0.0
# 2       3.957964       0.0
# 3       4.156746       0.0
# 4       4.355528       0.0
# ...          ...       ...
# 8104  178.418546       0.0
# 8105  178.418546       0.0
# 8106  178.418546       0.0
# 8107  178.418546       0.0
# 8108  178.418546       0.0
#
# [8109 rows x 16 columns]

# %%
flights_database = '../data/flight/KDEN_KSEA_2023-01-01_2023-01-31.sqlite'

conn = sqlite3.connect(flights_database)

optimal_sv = pd.read_sql_query(f"""
        SELECT *
        FROM optimal_state_vector_weather
        LIMIT 10;
        """,
        conn)

conn.close()
optimal_sv
# Out:
#                                 flight_id  tmpf air_pressure air_density  \
# 0  a44565_1673808290_1673816496_KDEN_KSEA  None         None        None
# 1  a44565_1673808290_1673816496_KDEN_KSEA  None         None        None
# 2  a44565_1673808290_1673816496_KDEN_KSEA  None         None        None
# 3  a44565_1673808290_1673816496_KDEN_KSEA  None         None        None
# 4  a44565_1673808290_1673816496_KDEN_KSEA  None         None        None
# 5  a44565_1673808290_1673816496_KDEN_KSEA  None         None        None
# 6  a44565_1673808290_1673816496_KDEN_KSEA  None         None        None
# 7  a44565_1673808290_1673816496_KDEN_KSEA  None         None        None
# 8  a44565_1673808290_1673816496_KDEN_KSEA  None         None        None
# 9  a44565_1673808290_1673816496_KDEN_KSEA  None         None        None
#
#   clouds  sknt severity
# 0   None  None     None
# 1   None  None     None
# 2   None  None     None
# 3   None  None     None
# 4   None  None     None
# 5   None  None     None
# 6   None  None     None
# 7   None  None     None
# 8   None  None     None
# 9   None  None     None

# %%
csv_files = ['../data/flight/' + f for f in os.listdir('../data/flight') if f.startswith('optimal_' + flights_database.split('/')[-1].replace('.sqlite','')) and f.endswith('.csv')]
csv_files
# Out:
# ['../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a3649a_1673032170_1673040502_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a27f07_1674604688_1674614127_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a28de3_1674171821_1674180496_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a32ad5_1674524954_1674534011_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a5c2dd_1674171334_1674180026_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a441d6_1673400921_1673409014_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a2919a_1672870456_1672879758_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a44938_1674100898_1674109421_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a33d68_1675130645_1675139747_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ac1afa_1674966717_1674975174_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_aacd50_1674833732_1674843263_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a44570_1674739433_1674748085_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a3472f_1673573510_1673582305_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a4491c_1674700664_1674709276_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a5d007_1673101537_1673110407_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a0acff_1673934953_1673943269_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a29551_1674583998_1674593341_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a3b414_1674613983_1674622873_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a25b3f_1673999464_1674008166_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abeb7c_1675045195_1675053749_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a73220_1672859294_1672868543_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abc3c6_1673935807_1673944518_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a6ee47_1672975916_1672984559_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a3efa2_1674016358_1674024728_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a33d68_1674074970_1674083427_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a43e83_1674878378_1674887548_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a42323_1672768110_1672776368_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a56866_1673204380_1673212915_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a23a02_1675145191_1675154097_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a3117c_1672849202_1672858928_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a3e55a_1672598684_1672607288_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a1ff46_1673838461_1673846837_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a44cfd_1674567430_1674576256_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a2d92a_1674929840_1674938634_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a28904_1673064630_1673073464_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a52c4f_1674861844_1674871115_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ad1857_1674152430_1674161156_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ad4afb_1674445624_1674454409_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abb90d_1673365869_1673374460_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a0acbb_1674227540_1674236039_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a33d68_1673551683_1673560409_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a07b8f_1672861629_1672871320_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abc0e4_1674834902_1674844385_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ac0bb9_1673752602_1673760982_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a44960_1674441764_1674450669_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a744b3_1672893296_1672902046_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ad3c1f_1672956826_1672965381_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a39fb7_1673668541_1673677226_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a2b12d_1674758807_1674767997_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ab5ade_1672983366_1672991861_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a43458_1674787841_1674798355_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ad01ab_1672753383_1672761742_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a360e3_1674826105_1674835635_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_acf846_1674653310_1674662139_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ad99f9_1673270640_1673280198_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a288ff_1674792094_1674801436_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a35975_1674864408_1674873419_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a44591_1674051183_1674059682_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a326d1_1674740762_1674749853_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a2228b_1674346791_1674355286_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a28904_1674446674_1674455360_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a340d2_1674756450_1674765388_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_aa4a9b_1673243154_1673252442_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a6ca7f_1672756152_1672764404_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a300a9_1673845577_1673853839_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a448f2_1674270576_1674278751_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a494eb_1673376714_1673385461_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abae62_1674797250_1674806930_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ada167_1672524657_1672534041_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ac006d_1673589139_1673598169_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a62825_1674430362_1674439323_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ab1644_1672603218_1672611926_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a0fbb7_1673277502_1673287135_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ac247a_1672957898_1672966116_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a9d5df_1673969441_1673977962_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a3411f_1673919303_1673927873_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ac015f_1675126580_1675135479_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a2d573_1673393465_1673401724_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a01037_1673124740_1673133229_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ad3c1f_1675053113_1675061922_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a28928_1673842845_1673851251_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a43e5e_1673018966_1673027568_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a5ec61_1674411570_1674420222_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a53774_1673913042_1673921355_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a44cda_1674394905_1674403589_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a44cda_1674136415_1674144953_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a1cc1f_1674222602_1674231599_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a32e8c_1674501592_1674511210_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a013ee_1673233457_1673242821_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a326d1_1672601433_1672609895_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a44940_1672874447_1672883891_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a495b4_1675002768_1675010953_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abfd23_1673994305_1674003034_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a41632_1673363597_1673372845_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a335fa_1674242858_1674251460_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_{flight_id}.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a4c865_1674258764_1674267102_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a3411f_1673185878_1673194105_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a3411f_1674933984_1674942689_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a34ae6_1674332506_1674341179_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a1cc1f_1675103701_1675112698_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a33d68_1674007866_1674016368_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a61f05_1674480229_1674489077_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a622bc_1672947709_1672955980_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a720eb_1673062490_1673071188_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_aa56d8_1674745710_1674754644_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a57f04_1674087499_1674096112_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a59197_1674951383_1674960200_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ada167_1675138122_1675146984_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a2bb83_1673578142_1673586874_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a5dee3_1674055264_1674063989_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a85f29_1675104253_1675113076_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_acdfa3_1674326672_1674335309_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a451cf_1673702465_1673711049_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a1c868_1673227863_1673236886_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a836fb_1674413435_1674422433_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a0acf9_1673756360_1673764683_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a12429_1672944919_1672952996_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_aacd50_1672541456_1672550735_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abb1c2_1674883580_1674892636_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a32fd5_1672802591_1672811573_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_acb46d_1674950038_1674958874_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a94b4b_1673722894_1673731098_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a27f07_1674186755_1674195514_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a01037_1672949116_1672957319_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ab68f9_1673752392_1673761257_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a4c865_1673319704_1673328959_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a35283_1674184411_1674193150_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a34e9d_1672755010_1672763243_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a43b85_1673616829_1673625261_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a43e5b_1673582479_1673591530_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a5db2c_1673118823_1673127694_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abd57e_1673794395_1673802586_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a2f584_1673826776_1673834947_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a44ca0_1673449754_1673458619_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ac205f_1673044399_1673052823_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abe101_1674357240_1674366070_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a4f5a0_1674431125_1674440006_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ab0158_1674962737_1674971500_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_aaa58b_1674967233_1674975706_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a3649a_1673482345_1673492060_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ad8ed4_1674843276_1674852608_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a61592_1673566002_1673575099_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a06a5a_1672974723_1672983797_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ad99f9_1674912322_1674921467_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a52c4f_1673997844_1674006561_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a49d16_1673270730_1673279858_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a30460_1673653281_1673661850_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a340d2_1673547555_1673556737_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ac16da_1673304007_1673313179_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abe496_1673832018_1673840413_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abf2ea_1672811198_1672819833_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a7a90e_1672860194_1672868980_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a32367_1674352801_1674361646_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abb995_1674858929_1674867917_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a3a8ef_1674014640_1674022834_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a2b060_1672891890_1672900679_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a85f20_1673290088_1673299432_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a29551_1673188855_1673197397_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a61592_1674516486_1674525640_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a3a086_1675055070_1675063438_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a4417d_1674223412_1674231857_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a5fd2d_1672837502_1672846743_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ac0ba7_1674619387_1674628210_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a3472f_1674438296_1674447237_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_aaa58b_1674487974_1674497068_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a94b29_1674327382_1674335929_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abf375_1674771973_1674781179_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a535c2_1674275220_1674283671_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_acdfa3_1673877516_1673886012_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a3a8ef_1674444619_1674453460_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a8f0bd_1673236612_1673245837_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abb624_1674087746_1674096294_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abb1c2_1674278790_1674287076_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a3472f_1673898348_1673906950_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a44943_1673789425_1673797424_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a07b8f_1673033588_1673041949_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abd230_1673504154_1673513765_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a4495c_1672972518_1672980815_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a7b779_1674516942_1674525851_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_acc1eb_1673617650_1673626537_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_aa4c1a_1673622752_1673631551_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ab62d3_1674598815_1674608141_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a2b8c5_1672606449_1672615130_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a9d626_1673461543_1673470244_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a3a0eb_1675093860_1675102588_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abc14d_1673227132_1673236098_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a61797_1673146371_1673155408_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a35254_1674760680_1674769569_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abaa0e_1674710532_1674718925_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a3271e_1675192748_1675201695_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a43f3c_1674479683_1674488572_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a38527_1675054294_1675062594_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ac07dc_1674193548_1674201935_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a146f1_1674950925_1674959448_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a2bbf2_1674614108_1674623604_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abefba_1673649034_1673657545_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a44918_1674787392_1674797061_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a4f39b_1673134117_1673143002_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a3a0ed_1673410481_1673419233_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ac20c4_1674144561_1674153140_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a0acfd_1673324792_1673333295_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a32ad5_1673465783_1673474754_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a7398e_1673912241_1673920821_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ad8766_1673672490_1673681189_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ad0f29_1672772838_1672781279_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a6f5b5_1673356790_1673365548_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ac2706_1675006280_1675014918_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_aa2ba4_1673467951_1673476497_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abf375_1674512915_1674522042_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a4c865_1674782485_1674792079_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_aa7abd_1673635976_1673644468_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a44ca0_1674652975_1674661535_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a4c865_1672886437_1672895536_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ac0bfb_1673676902_1673685349_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a52898_1672806331_1672815336_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abb1c2_1674540541_1674549128_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a441fb_1674913654_1674922657_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a3133c_1675087044_1675096338_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ac00d6_1673137109_1673145822_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a2919a_1674073508_1674082031_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a923a8_1672527139_1672536531_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a1235b_1674101898_1674110435_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a01037_1672602317_1672611355_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a5521c_1673892652_1673901039_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a44570_1675173878_1675182707_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a35254_1673011830_1673020197_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a5c899_1674137380_1674146262_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_aaa590_1673549645_1673558592_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abd1c5_1674625324_1674634048_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ac2836_1674107217_1674115679_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abeeea_1674575679_1674584722_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a2adf4_1673462597_1673471630_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a6c247_1673204201_1673212576_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a4cc1c_1673486506_1673495136_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a7016c_1672801759_1672810555_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a44962_1675051290_1675059611_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a339b1_1674267826_1674276117_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a35254_1672842175_1672851389_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a2e235_1672888673_1672897688_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a2228b_1674238894_1674247403_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a726fb_1673790204_1673798470_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a5d643_1673664436_1673672934_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a037b2_1673120618_1673129284_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a62f93_1675036116_1675044508_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a1235b_1674187298_1674195974_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a43e5e_1674573636_1674582546_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a32e8c_1673100201_1673108658_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a37986_1673531465_1673541340_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a451cf_1673532245_1673541671_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abd8a5_1674748434_1674757589_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a506d5_1675036962_1675045571_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a01037_1673207292_1673215565_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abb930_1673390223_1673398649_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a35254_1674847237_1674856409_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a923a8_1674499465_1674508467_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_aced21_1673583127_1673592059_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abe872_1673020668_1673029079_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a448d1_1674873656_1674883074_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a73059_1674939801_1674948416_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a51968_1673374966_1673383564_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a620f5_1674334950_1674343605_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a34ae6_1674416624_1674425469_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abe3e6_1674437636_1674446362_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ac1a95_1673910084_1673918429_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a54aae_1672796086_1672804565_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a1c868_1672784108_1672792467_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a582bb_1673220747_1673229539_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a34ae6_1675049778_1675058465_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a07b8f_1672776829_1672785249_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a05e02_1674141151_1674149738_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a41e2c_1673895244_1673903731_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a61b4e_1672879774_1672889019_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a3d425_1672977171_1672985977_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a9238a_1672780748_1672789085_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_aaa593_1673150822_1673159772_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a32367_1673746216_1673754489_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a535c2_1674672193_1674680939_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a3efa2_1674361052_1674370289_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a609d4_1674356794_1674365564_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a32367_1674587636_1674596622_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a5c899_1674087603_1674096201_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a59d63_1674567751_1674576770_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a0ad1b_1674706722_1674715326_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abc780_1672934521_1672943018_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a0acdd_1672931800_1672939968_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a54c60_1673306807_1673316220_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ac0818_1673563661_1673572408_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a2e045_1674011510_1674020093_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a61949_1674602705_1674611569_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a34e9d_1674100701_1674109155_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abb19c_1672549350_1672558473_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a612a6_1673831467_1673839565_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a2ce05_1673807048_1673815446_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a335fa_1674179884_1674188708_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a4b21b_1673393104_1673401479_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a19404_1674452475_1674461241_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ac07fd_1674169175_1674177881_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a8f0bd_1675191143_1675200041_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a2bb83_1673059411_1673068356_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ac2813_1673148000_1673157296_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a6aa6e_1673307776_1673316929_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a44565_1673808290_1673816496_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a9238a_1673030657_1673039409_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a5dee3_1675198135_1675207118_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a326d1_1673055027_1673063555_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a448f8_1674182328_1674191089_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abdce1_1675144872_1675153625_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a448d1_1673837092_1673845528_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a837a3_1673117492_1673126248_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a448d1_1675133714_1675142569_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abc455_1674686638_1674695198_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ac0519_1673885473_1673893869_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a44502_1673360066_1673368761_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abd8a5_1674229884_1674238155_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a24dc1_1674778946_1674788306_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a32367_1673379304_1673387625_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a8d4b0_1673981646_1673990194_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a24fb8_1673848121_1673856479_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abf949_1672867504_1672876739_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a2d92a_1675123318_1675132499_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a3b414_1673405360_1673413567_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a4f752_1673145585_1673154172_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a36e61_1673447111_1673455942_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a5f938_1674689679_1674698528_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a32367_1673637847_1673646328_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a339b1_1673488703_1673498767_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a4a0cd_1674826884_1674836199_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_abae8f_1673329447_1673338826_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a2b810_1674673462_1674682111_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a94b50_1675179141_1675188233_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a8d5a0_1674932240_1674940871_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a23a03_1674845593_1674857395_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a448d3_1673405297_1673413729_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_ac2813_1673970984_1673979378_KDEN_KSEA.csv',
#  '../data/flight/optimal_KDEN_KSEA_2023-01-01_2023-01-31_a335ad_1672966747_1672975259_KDEN_KSEA.csv']

# %%
'optimal_' + flights_database.replace('.sqlite','')
# Out:
# 'optimal_../data/flight/KDEN_KSEA_2023-01-01_2023-01-31'
